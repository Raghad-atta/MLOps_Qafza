# %% [markdown]
# # Initial Steps:
#
# 1. Access the attached files in the classroom and the data link on the Keegle website.
# 2. Download the complete dataset, read its contents, and analyze the relationships between the data points.
# 3. Download Ducker and configure its settings.
# 4. Open Docker and enter SQL commands to create the tables and assign the PK and FK values ​​according to the table relationships.
# 5. Verify that the table has been created correctly.
# 6. Execute some join commands to ensure that the FK values ​​are correctly selected.
# all screen shots are attached.

# %% [markdown]
# # Relationships
# customers 1──►N orders (customer_id)
# orders 1──►1 reviwes (order_id)
# orders 1──►N payments (order_id)
# orders 1──►N order items (order_id)
# sellers 1──►N order items (seller_id)
# products 1──►N order items (product_id)

# %% [markdown]
# # Result
# all the file are inside docker container and the finl task result will emproved in days to match the mentor instructions 💪
